# %%
import os
import io
import wave
import librosa
import soundfile as sf
import noisereduce as nr
import webrtcvad
from pydub import AudioSegment, silence

# %%
def preprocess_flac_files(
    input_folder: str,
    output_folder: str,
    min_silence_len: int = 400,
    silence_thresh: int = -50,
    keep_silence: int = 200,
    vad_aggressiveness: int = 3,
    target_sr: int = 16000
):
    """
    Processes a two-level folder structure of FLAC files:
      - Splits on silence,
      - (Optionally) applies WebRTC Voice Activity Detection,
      - Noise reduction,
      - Volume normalization,
      - Resamples to target_sr,
      - Saves the processed audio with the same folder structure.

    Args:
        input_folder (str): Root directory containing user folders (1..150).
        output_folder (str): Where to save processed files (mirroring structure).
        min_silence_len (int): Minimum length of silence (ms) for pydub splitting.
        silence_thresh (int): Silence threshold in dBFS for pydub.
        keep_silence (int): How many ms of silence to keep at each split edge.
        vad_aggressiveness (int): 0-3 (webrtcvad aggressiveness; higher = more aggressive).
        target_sr (int): Target sample rate for final audio.
    """
    os.makedirs(output_folder, exist_ok=True)

    # Iterate over each user folder (e.g. "1", "2", ..., "150")
    for user_dir in os.listdir(input_folder):
        user_input_path = os.path.join(input_folder, user_dir)
        if not os.path.isdir(user_input_path):
            continue  # skip anything that's not a directory

        # Create matching directory in the output folder
        user_output_path = os.path.join(output_folder, user_dir)
        os.makedirs(user_output_path, exist_ok=True)

        # Process each .flac file in this user's folder
        for filename in os.listdir(user_input_path):
            if filename.lower().endswith(".flac"):
                file_path = os.path.join(user_input_path, filename)
                
                # -------------------------------------------------
                # 1) READ FLAC with pydub as AudioSegment
                # -------------------------------------------------
                audio_segment = AudioSegment.from_file(file_path, format="flac")
                print(f"Loaded: {file_path} [dBFS={audio_segment.dBFS:.2f}]")

                # -------------------------------------------------
                # 2) SPLIT BY SILENCE (pydub)
                # -------------------------------------------------
                # This splits the audio into chunks where each chunk is separated
                # by >= min_silence_len ms of silence at < silence_thresh dBFS.
                # keep_silence (ms) keeps a bit of silence at edges for continuity.
                chunks = silence.split_on_silence(
                    audio_segment,
                    min_silence_len=min_silence_len,
                    silence_thresh=silence_thresh,
                    keep_silence=keep_silence
                )

                # If no chunks found (completely silent?), just treat the entire file as one chunk
                if not chunks:
                    chunks = [audio_segment]

                # -------------------------------------------------
                # 3) PROCESS EACH CHUNK
                # -------------------------------------------------
                for i, chunk in enumerate(chunks, start=1):
                    # (Optional) Convert chunk to PCM for WebRTC VAD
                    # Note: pydub chunk sample_width might be 2 or 4 bytes, etc.
                    # We need 16-bit PCM for webrtcvad, with sample rates 8k, 16k, 32k, or 48k.
                    chunk_frame_rate = chunk.frame_rate
                    chunk = chunk.set_frame_rate(target_sr).set_channels(1).set_sample_width(2)
                    chunk_frame_rate = chunk.frame_rate  # Now should be target_sr

                    # Optionally run WebRTC VAD to further trim non-speech
                    # If your data is already well-split by silence, you can skip this step.
                    chunk = apply_webrtc_vad(chunk, vad_aggressiveness)

                    # Skip empty chunks after VAD
                    if len(chunk) < 10:  
                        continue

                    # Convert chunk (pydub) back to numpy for noisereduce + librosa
                    buffer = io.BytesIO()
                    chunk.export(buffer, format="wav")  # Export chunk as WAV in memory
                    buffer.seek(0)
                    audio_data, _ = sf.read(buffer, dtype='float32')
                    
                    # -------------------------------------------------
                    # 4) NOISE REDUCTION (noisereduce)
                    # -------------------------------------------------
                    reduced_audio = nr.reduce_noise(y=audio_data, sr=target_sr)

                    # -------------------------------------------------
                    # 5) VOLUME NORMALIZATION (librosa)
                    # -------------------------------------------------
                    normalized_audio = librosa.util.normalize(reduced_audio)

                    # -------------------------------------------------
                    # 6) RESAMPLE to target_sr (already at target_sr, but just in case)
                    # -------------------------------------------------
                    # If you want to absolutely ensure sampling rate:
                    final_audio = librosa.resample(normalized_audio, orig_sr=target_sr, target_sr=target_sr)

                    # -------------------------------------------------
                    # 7) SAVE the processed chunk
                    # -------------------------------------------------
                    base_name = os.path.splitext(filename)[0]  # e.g. audio_1
                    output_filename = f"{base_name}_chunk_{i}_cleaned.wav"
                    output_file_path = os.path.join(user_output_path, output_filename)

                    sf.write(output_file_path, final_audio, target_sr)
                    print(f"  -> Saved chunk {i}: {output_file_path}")

# %%
def apply_webrtc_vad(audio_segment: AudioSegment, aggressiveness: int = 3) -> AudioSegment:
    """
    Applies WebRTC VAD to a mono, 16-bit AudioSegment at 8/16/32/48 kHz.
    Trims out frames flagged as non-voice. 
    Returns a smaller AudioSegment containing only voiced frames.

    NOTE: pydub's chunk must already be set to 16-bit, 1 channel, 
    and a supported sample rate before calling this function.
    """
    vad = webrtcvad.Vad()
    vad.set_mode(aggressiveness)

    sample_rate = audio_segment.frame_rate
    raw_data = audio_segment.raw_data
    bytes_per_frame = 2  # since we set sample_width=2

    # WebRTC VAD expects frames of 10, 20, or 30 ms
    frame_ms = 30  
    frame_size = int(sample_rate * (frame_ms / 1000.0))  # samples per frame

    voiced_frames = bytearray()

    # Process the raw_data in chunks of 'frame_size * bytes_per_frame'
    for start in range(0, len(raw_data), frame_size * bytes_per_frame):
        end = start + (frame_size * bytes_per_frame)
        if end > len(raw_data):
            break
        frame = raw_data[start:end]
        # VAD check
        is_speech = vad.is_speech(frame, sample_rate)
        if is_speech:
            voiced_frames.extend(frame)

    # Build a new AudioSegment from the voiced frames
    voiced_segment = AudioSegment(
        data=bytes(voiced_frames),
        sample_width=audio_segment.sample_width,
        frame_rate=sample_rate,
        channels=1
    )
    return voiced_segment

# %%
if __name__ == "__main__":
    input_folder = r"C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase" 
    output_folder = r"C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output"
    
    preprocess_flac_files(
        input_folder=input_folder,
        output_folder=output_folder,
        min_silence_len=400,    # pydub: ms of silence
        silence_thresh=-50,     # pydub: dBFS threshold
        keep_silence=200,       # pydub: keep 200ms
        vad_aggressiveness=3,   # webrtcvad: 0-3
        target_sr=16000         # final sample rate
    )
# Out:
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-11.flac [dBFS=-26.00]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-11_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-11_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-12.flac [dBFS=-25.70]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-12_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-13.flac [dBFS=-25.83]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-13_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-13_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-13_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-14.flac [dBFS=-26.34]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-14_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-15.flac [dBFS=-25.90]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-15_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-16.flac [dBFS=-28.02]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-16_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-17.flac [dBFS=-24.78]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-18.flac [dBFS=-24.78]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-18_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-19.flac [dBFS=-25.78]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-19_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\1\1-20.flac [dBFS=-27.14]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-20_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-20_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\1\1-20_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-11.flac [dBFS=-21.27]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-11_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-12.flac [dBFS=-19.41]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-12_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-13.flac [dBFS=-20.47]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-14.flac [dBFS=-21.84]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-14_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-15.flac [dBFS=-21.06]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-15_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-16.flac [dBFS=-22.12]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-16_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-17.flac [dBFS=-22.51]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-18.flac [dBFS=-19.59]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-18_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-19.flac [dBFS=-21.45]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-19_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\10\10-20.flac [dBFS=-19.24]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\10\10-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-11.flac [dBFS=-35.74]
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-11_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-11_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-12.flac [dBFS=-34.49]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-12_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-13.flac [dBFS=-36.00]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-13_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-13_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-14.flac [dBFS=-33.64]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-14_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-14_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-15.flac [dBFS=-34.47]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-15_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-16.flac [dBFS=-33.97]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-16_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-16_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-17.flac [dBFS=-34.79]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-17_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-17_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-17_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-17_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-18.flac [dBFS=-35.85]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-18_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-19.flac [dBFS=-34.78]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-19_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\100\100-20.flac [dBFS=-34.07]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\100\100-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-11.flac [dBFS=-22.60]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-11_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-11_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-11_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-12.flac [dBFS=-24.88]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-12_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-12_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-13.flac [dBFS=-24.03]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-13_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-13_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-14.flac [dBFS=-23.52]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-14_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-15.flac [dBFS=-23.97]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-15_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-15_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-16.flac [dBFS=-22.07]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-16_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-17.flac [dBFS=-22.35]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-17_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-17_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-17_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-17_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-18.flac [dBFS=-24.18]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-18_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-19.flac [dBFS=-22.70]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-19_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\101\101-20.flac [dBFS=-22.74]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-20_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\101\101-20_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-11.flac [dBFS=-25.93]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-11_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-12.flac [dBFS=-26.87]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-12_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-13.flac [dBFS=-29.10]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-13_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-13_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-13_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-14.flac [dBFS=-32.35]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-14_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-15.flac [dBFS=-27.04]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-15_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-15_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-16.flac [dBFS=-28.12]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-16_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-17.flac [dBFS=-27.12]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-17_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-17_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-18.flac [dBFS=-30.69]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-18_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-18_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-18_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-19.flac [dBFS=-29.63]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-19_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-19_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\102\102-20.flac [dBFS=-27.10]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-20_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-20_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\102\102-20_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-11.flac [dBFS=-30.20]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-11_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-12.flac [dBFS=-30.23]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-12_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-13.flac [dBFS=-30.96]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-14.flac [dBFS=-28.19]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-14_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-15.flac [dBFS=-31.01]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-15_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-16.flac [dBFS=-29.39]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-16_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-17.flac [dBFS=-30.62]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-18.flac [dBFS=-29.96]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-18_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-19.flac [dBFS=-31.06]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-19_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\103\103-20.flac [dBFS=-29.25]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\103\103-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-11.flac [dBFS=-24.83]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-11_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-11_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-11_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-12.flac [dBFS=-21.36]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-12_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-13.flac [dBFS=-23.61]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-14.flac [dBFS=-22.97]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-14_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-15.flac [dBFS=-23.84]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-15_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-16.flac [dBFS=-23.41]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-16_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-17.flac [dBFS=-19.79]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-18.flac [dBFS=-21.29]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-18_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-19.flac [dBFS=-19.30]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-19_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\104\104-20.flac [dBFS=-24.63]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\104\104-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-11.flac [dBFS=-22.43]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-11_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-12.flac [dBFS=-21.67]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-12_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-13.flac [dBFS=-22.94]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-14.flac [dBFS=-23.52]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-14_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-15.flac [dBFS=-23.52]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-15_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-16.flac [dBFS=-21.66]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-16_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-17.flac [dBFS=-20.24]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-18.flac [dBFS=-19.45]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-18_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-19.flac [dBFS=-18.02]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-19_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\105\105-20.flac [dBFS=-22.35]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\105\105-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-11.flac [dBFS=-25.33]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-11_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-11_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-11_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-12.flac [dBFS=-25.33]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-12_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-13.flac [dBFS=-24.27]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-13_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-13_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-14.flac [dBFS=-25.49]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-14_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-15.flac [dBFS=-26.15]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-15_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-15_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-16.flac [dBFS=-24.39]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-16_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-16_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-16_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-17.flac [dBFS=-22.23]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-18.flac [dBFS=-25.81]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-18_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-19.flac [dBFS=-23.87]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-19_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\106\106-20.flac [dBFS=-23.71]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\106\106-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-11.flac [dBFS=-24.21]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-11_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-12.flac [dBFS=-22.97]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-12_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-13.flac [dBFS=-22.02]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-14.flac [dBFS=-23.84]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-14_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-15.flac [dBFS=-25.72]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-15_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-16.flac [dBFS=-24.87]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-16_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-17.flac [dBFS=-23.20]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-18.flac [dBFS=-27.07]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-18_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-19.flac [dBFS=-22.60]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-19_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\107\107-20.flac [dBFS=-26.40]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\107\107-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-11.flac [dBFS=-27.64]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-11_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-11_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-12.flac [dBFS=-29.92]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-12_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-12_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-12_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-13.flac [dBFS=-31.15]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-13_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-13_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-13_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-13_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-14.flac [dBFS=-32.17]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-14_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-15.flac [dBFS=-31.61]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-15_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-15_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-16.flac [dBFS=-30.27]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-16_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-16_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-17.flac [dBFS=-31.88]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-17_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-17_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-17_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-17_chunk_4_cleaned.wav
#   -> Saved chunk 5: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-17_chunk_5_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-18.flac [dBFS=-31.95]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-18_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-18_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-19.flac [dBFS=-31.91]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-19_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-19_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\108\108-20.flac [dBFS=-29.10]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-20_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-20_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\108\108-20_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-11.flac [dBFS=-33.26]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-11_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-11_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-11_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-12.flac [dBFS=-32.76]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-12_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-13.flac [dBFS=-33.92]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-14.flac [dBFS=-34.19]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-14_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-14_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-15.flac [dBFS=-30.78]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-15_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-16.flac [dBFS=-33.61]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-16_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-17.flac [dBFS=-32.89]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-18.flac [dBFS=-30.30]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-18_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-18_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-19.flac [dBFS=-29.13]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-19_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\109\109-20.flac [dBFS=-30.51]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\109\109-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\11\11-11.flac [dBFS=-23.18]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-11_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-11_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\11\11-12.flac [dBFS=-24.40]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-12_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\11\11-13.flac [dBFS=-23.36]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-13_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-13_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\11\11-14.flac [dBFS=-24.78]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-14_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-14_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-14_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\11\11-15.flac [dBFS=-18.70]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-15_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\11\11-16.flac [dBFS=-17.97]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-16_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-16_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\11\11-17.flac [dBFS=-24.40]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-17_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-17_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-17_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\11\11-17_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\11\11-18.flac [dBFS=-18.02]
# ...
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-16_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-16_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-16_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\59\59-17.flac [dBFS=-23.38]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-17_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-17_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-17_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\59\59-18.flac [dBFS=-21.51]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-18_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-18_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\59\59-19.flac [dBFS=-22.07]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-19_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\59\59-20.flac [dBFS=-23.13]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-20_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-20_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\59\59-20_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-11.flac [dBFS=-22.68]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-11_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-12.flac [dBFS=-24.66]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-12_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-13.flac [dBFS=-21.51]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-14.flac [dBFS=-25.30]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-14_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-15.flac [dBFS=-24.89]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-15_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-16.flac [dBFS=-21.02]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-16_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-17.flac [dBFS=-19.94]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-18.flac [dBFS=-22.46]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-18_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-19.flac [dBFS=-24.67]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-19_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-19_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\6\6-20.flac [dBFS=-23.33]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\6\6-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-11.flac [dBFS=-17.25]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-11_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-12.flac [dBFS=-17.38]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-12_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-13.flac [dBFS=-16.72]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-14.flac [dBFS=-15.07]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-14_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-15.flac [dBFS=-19.27]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-15_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-16.flac [dBFS=-17.44]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-16_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-17.flac [dBFS=-14.50]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-18.flac [dBFS=-17.17]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-18_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-19.flac [dBFS=-18.32]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-19_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-19_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\60\60-20.flac [dBFS=-15.09]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\60\60-20_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-11.flac [dBFS=-20.63]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-11_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-11_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-11_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-12.flac [dBFS=-22.57]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-12_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-12_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-12_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-12_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-13.flac [dBFS=-19.52]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-13_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-13_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-14.flac [dBFS=-17.68]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-14_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-14_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-14_chunk_3_cleaned.wav
#   -> Saved chunk 4: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-14_chunk_4_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-15.flac [dBFS=-22.58]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-15_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-15_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-15_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-16.flac [dBFS=-19.37]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-16_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-16_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-17.flac [dBFS=-16.84]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-17_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-17_chunk_2_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-18.flac [dBFS=-21.94]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-18_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-18_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-19.flac [dBFS=-24.15]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-19_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-19_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-19_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\61\61-20.flac [dBFS=-24.36]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-20_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-20_chunk_2_cleaned.wav
#   -> Saved chunk 3: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\61\61-20_chunk_3_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\62\62-11.flac [dBFS=-18.68]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-11_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\62\62-12.flac [dBFS=-17.12]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-12_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\62\62-13.flac [dBFS=-19.39]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-13_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\62\62-14.flac [dBFS=-18.51]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-14_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\62\62-15.flac [dBFS=-17.67]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-15_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\62\62-16.flac [dBFS=-17.82]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-16_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\62\62-17.flac [dBFS=-19.40]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-17_chunk_1_cleaned.wav
# Loaded: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\differentPhrase\62\62-18.flac [dBFS=-19.80]
#   -> Saved chunk 1: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-18_chunk_1_cleaned.wav
#   -> Saved chunk 2: C:\Users\VICTUS\Voice\A Dataset for Voice-Based Human Identity Recognition\output\62\62-18_chunk_2_cleaned.wav
